# %%
with open("covid.all.aln",'r') as fr:
    for line in fr:
        if line.startswith("MUSCLE"):
            continue
        if "*" in line:
            continue
        l = line.strip().split()
        if l:
            genbank_id = l[0]
            seq = l[1]
            if genbank_id not in seq_dict:
                seq_dict[genbank_id] = seq
            else:
                seq_dict[genbank_id] += seq

with open("covid.aln.fasta",'w') as fw:
    for k,v in seq_dict.items():
        fw.write(">"+k+"\n")
        fw.write(v+"\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4ad52f579e60> in <module>
#       9             genbank_id = l[0]
#      10             seq = l[1]
# ---> 11             if genbank_id not in seq_dict:
#      12                 seq_dict[genbank_id] = seq
#      13             else:
#
# NameError: name 'seq_dict' is not defined
