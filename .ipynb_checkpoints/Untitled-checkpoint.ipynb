# %%
#8.3.1 blast_example_1.py

# %%
from Bio.Blast import NCBIWWW

# %%
from Bio import SeqIO

# %%
record = SeqIO.read("sequence.fasta", format="fasta")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e280cd5788e5> in <module>
# ----> 1 record = SeqIO.read("sequence.fasta", format="fasta")
#
# C:\anaconda3\lib\site-packages\Bio\SeqIO\__init__.py in read(handle, format, alphabet)
#     652     to read multiple records from the handle.
#     653     """
# --> 654     iterator = parse(handle, format, alphabet)
#     655     try:
#     656         record = next(iterator)
#
# C:\anaconda3\lib\site-packages\Bio\SeqIO\__init__.py in parse(handle, format, alphabet)
#     605     iterator_generator = _FormatToIterator.get(format)
#     606     if iterator_generator:
# --> 607         return iterator_generator(handle)
#     608     if format in AlignIO._FormatToIterator:
#     609         # Use Bio.AlignIO to read in the alignments
#
# C:\anaconda3\lib\site-packages\Bio\SeqIO\FastaIO.py in __init__(self, source, alphabet, title2ids)
#     181             raise ValueError("The alphabet argument is no longer supported")
#     182         self.title2ids = title2ids
# --> 183         super().__init__(source, mode="t", fmt="Fasta")
#     184
#     185     def parse(self, handle):
#
# C:\anaconda3\lib\site-packages\Bio\SeqIO\Interfaces.py in __init__(self, source, alphabet, mode, fmt)
#      45             raise ValueError("The alphabet argument is no longer supported")
#      46         try:
# ---> 47             self.stream = open(source, "r" + mode)
#      48             self.should_close_stream = True
#      49         except TypeError:  # not a path, assume we received a stream
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sequence.fasta'

# %%
print(record.seq)
